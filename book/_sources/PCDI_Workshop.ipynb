# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %% [markdown]
# | Thema                                                                                                                                                                                                                                                                                                    	| Zeit                                       	|
# |:----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------	|--------------------------------------------	:|
# | Basics<br>* Grundlagen optischer Abbildungen<br>* Lineare verschiebungsinvariante Systeme (LSI)<br>* Impulsantwort (PSF) eines LSI-Systems<br>* Übertragungsfunktion eines LSI-Systems                                                                                                                   	| 20                                         	|
# | PSF-Engineering                                                                                                                                                                                                                                                                                          	| 10                                         	|
# | Vorwärtsmodell der Bildentstehung                                                                                                                                                                                                                                                                        	| 5                                          	|
# | Rekonstruktionsverfahren<br>* Inverses Filter<br>* Wiener Filter<br>* Richardson-Lucy Algorithmus<br>* Bayes'sche Ansätze<br>  * Maximum a-posteriori-Ansatz<br>  * Half Quadratic Splitting-Methode<br>  * Alternating Direction Method of Multipliers (ADMM)<br>  * Rolle und Wahl des Regularisierers 	| <br>5<br>5<br>5<br><br>5<br>10<br>10<br>10 	|
# | Typen von Phasenmasken<br>* Systematische Phasenvariation (kubisch, annular, spiral)<br>* Zufällige Phasenvariation<br>* Gelernte Phasenvariation                                                                                                                                                        	| <br>5<br>5<br>15                           	|
# | Fragen                                                                                                                                                                                                                                                                                                   	| 15                                         	|
# | Diskussion weiteres Vorgehen / welche Verfahren                                                                                                                                                                                                                                                          	| 30+                                        	|
